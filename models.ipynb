# %%
import os
from PIL import Image
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# c:\Users\elgin\OneDrive\Documents\NTU\ML0004 Group Project\SC4000_Group_Project

# %%
from PIL import Image

im = Image.open(f"{cwd}/train/0a0da090aa9f0342444a7df4dc250c66.jpg")
width, height = im.size
print(f'Width: {width}, Height: {height}')
# Out:
# Width: 393, Height: 470

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, tight_layout = True)
fig.suptitle('Distribution of pawpularity score (Train)')

train_df = pd.read_csv(f"{cwd}/train.csv")
axs.hist(train_df['Pawpularity'])
# Out:
# (array([ 405., 1012., 2779., 2340., 1363.,  725.,  442.,  285.,  173.,
#          388.]),
#  array([  1. ,  10.9,  20.8,  30.7,  40.6,  50.5,  60.4,  70.3,  80.2,
#          90.1, 100. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Data augmentation

# %% [markdown]
# Testing models

# %%
#Pre-trained models

#1) Swin large 384

# Load model directly
from transformers import AutoImageProcessor, AutoModelForImageClassification

processor = AutoImageProcessor.from_pretrained("microsoft/swin-large-patch4-window12-384-in22k")
model = AutoModelForImageClassification.from_pretrained("microsoft/swin-large-patch4-window12-384-in22k")
